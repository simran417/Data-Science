# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [36 27 23 44 23 41 12 49 48 30 34 10 27 32 23 11 39 52 51 50 59 16 43 11
#  38 27 18 34 18 18 52 21 30 27 47 48 52 10 52 59 19 20 38 14 21 29 38 41
#  27 56]

# %%
no=[36, 27, 23, 44, 23, 41, 12, 49, 48, 30, 34, 10, 27, 32, 23, 11, 39, 52, 51, 50, 59, 16, 43, 11,
 38, 27, 18, 34, 18, 18, 52, 21, 30, 27, 47, 48, 52, 10, 52, 59, 19, 20, 38, 14, 21, 29, 38, 41,
 27, 56]
plt.title("histogram")
plt.xlabel("x-axis")
plt.ylabel("y-label")
l=[10,20,30,40,50,60]
# plt.hist(no,color="pink",bins=l,edgecolor="black")
# plt.hist(no,"auto",(0,100),edgecolor="black",cumulative=-1)
# bottom function is used to change the bottom
# plt.hist(no,edgecolor="black",bottom=10)

# to change histogram type we use histtype()
# plt.hist(no,edgecolor="black",histtype="step")

# to change the orientation:
# plt.hist(no,edgecolor="black",orientation="horizontal",rwidth=0.8)

# to set the graph according to log:
plt.hist(no,edgecolor="black",log=True,label="python")
plt.legend()
plt.axvline(45,color="red",label="line")
plt.grid()
plt.show()
